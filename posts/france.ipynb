# %% [raw]
# ---
# title: "프랑스혁명"
# author: "강정혁"
# date: "01/02/2025"
# ---

# %% [markdown]
# # 프랑스 혁명

# %% [markdown]
# 루이

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 혁명의 전개

# %% [markdown]
# 삼부회 소집

# %% [markdown]
# ![image.png](attachment:image.png)
